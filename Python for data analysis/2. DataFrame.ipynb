# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
import webbrowser
website = 'http://en.wikipedia.org/wiki/NFL_win-loss_records'
webbrowser.open(website)
# Out:
# True

# %%
nfl_frame = pd.read_clipboard()
nfl_frame
# Out:
#    Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0     1           Dallas Cowboys    882  502   374     6  0.573
# 1     2        Green Bay Packers  1,336  737   562    37  0.565
# 2     3            Chicago Bears  1,370  749   579    42  0.562
# 3     4           Miami Dolphins    800  445   351     4  0.559
# 4     5  New England Patriots[b]    884  489   386     9  0.558
#
#    First NFL Season   Division
# 0              1960   NFC East
# 1              1921  NFC North
# 2              1920  NFC North
# 3              1966   AFC East
# 4              1960   AFC East

# %%
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied', 'Pct.', 'First NFL Season',
#        'Division'],
#       dtype='object')

# %%
nfl_frame['First NFL Season']
# Out:
# 0    1960
# 1    1921
# 2    1920
# 3    1966
# 4    1960
# Name: First NFL Season, dtype: int64

# %%
 nfl_frame.Team          #For single word column name
# Out:
# 0             Dallas Cowboys
# 1          Green Bay Packers
# 2              Chicago Bears
# 3             Miami Dolphins
# 4    New England Patriots[b]
# Name: Team, dtype: object

# %%
#To grab multiple columns
DataFrame(nfl_frame, columns=['Team', 'First NFL Season', 'GP'])
# Out:
#                       Team  First NFL Season     GP
# 0           Dallas Cowboys              1960    882
# 1        Green Bay Packers              1921  1,336
# 2            Chicago Bears              1920  1,370
# 3           Miami Dolphins              1966    800
# 4  New England Patriots[b]              1960    884

# %%
#How pandas deals with undefined column names
DataFrame(nfl_frame, columns=['Team', 'First NFL Season', 'GP', 'Stadium'])
# Out:
#                       Team  First NFL Season     GP  Stadium
# 0           Dallas Cowboys              1960    882      NaN
# 1        Green Bay Packers              1921  1,336      NaN
# 2            Chicago Bears              1920  1,370      NaN
# 3           Miami Dolphins              1966    800      NaN
# 4  New England Patriots[b]              1960    884      NaN

# %%
nfl_frame
# Out:
#    Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0     1           Dallas Cowboys    882  502   374     6  0.573
# 1     2        Green Bay Packers  1,336  737   562    37  0.565
# 2     3            Chicago Bears  1,370  749   579    42  0.562
# 3     4           Miami Dolphins    800  445   351     4  0.559
# 4     5  New England Patriots[b]    884  489   386     9  0.558
#
#    First NFL Season   Division
# 0              1960   NFC East
# 1              1921  NFC North
# 2              1920  NFC North
# 3              1966   AFC East
# 4              1960   AFC East

# %%
# To retrieve first few rows of a DataFrame
nfl_frame.head(3)    #By default 5
# Out:
#    Rank               Team     GP  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1     Dallas Cowboys    882  502   374     6  0.573              1960
# 1     2  Green Bay Packers  1,336  737   562    37  0.565              1921
# 2     3      Chicago Bears  1,370  749   579    42  0.562              1920
#
#     Division
# 0   NFC East
# 1  NFC North
# 2  NFC North

# %%
#To retrieve end rows
nfl_frame.tail(3)
# Out:
#    Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 2     3            Chicago Bears  1,370  749   579    42  0.562
# 3     4           Miami Dolphins    800  445   351     4  0.559
# 4     5  New England Patriots[b]    884  489   386     9  0.558
#
#    First NFL Season   Division
# 2              1920  NFC North
# 3              1966   AFC East
# 4              1960   AFC East

# %%
#To view a particular row by index
nfl_frame.iloc[3]
# Out:
# Rank                             4
# Team                Miami Dolphins
# GP                             800
# Won                            445
# Lost                           351
# Tied                             4
# Pct.                         0.559
# First NFL Season              1966
# Division                  AFC East
# Name: 3, dtype: object

# %%
# To assign values to entire column
nfl_frame['Stadium'] = "Levi's Stadium"
nfl_frame
# Out:
#    Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0     1           Dallas Cowboys    882  502   374     6  0.573
# 1     2        Green Bay Packers  1,336  737   562    37  0.565
# 2     3            Chicago Bears  1,370  749   579    42  0.562
# 3     4           Miami Dolphins    800  445   351     4  0.559
# 4     5  New England Patriots[b]    884  489   386     9  0.558
#
#    First NFL Season   Division         Stadium
# 0              1960   NFC East  Levi's Stadium
# 1              1921  NFC North  Levi's Stadium
# 2              1920  NFC North  Levi's Stadium
# 3              1966   AFC East  Levi's Stadium
# 4              1960   AFC East  Levi's Stadium

# %%
nfl_frame['Stadium'] = np.arange(10,15)
nfl_frame
# Out:
#    Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0     1           Dallas Cowboys    882  502   374     6  0.573
# 1     2        Green Bay Packers  1,336  737   562    37  0.565
# 2     3            Chicago Bears  1,370  749   579    42  0.562
# 3     4           Miami Dolphins    800  445   351     4  0.559
# 4     5  New England Patriots[b]    884  489   386     9  0.558
#
#    First NFL Season   Division  Stadium
# 0              1960   NFC East       10
# 1              1921  NFC North       11
# 2              1920  NFC North       12
# 3              1966   AFC East       13
# 4              1960   AFC East       14

# %%
#To add Series to a DataFrame
stadiums = Series(["Levi's Stadium", "AT&T Stadium"], index=[4,0])
stadiums
# Out:
# 4    Levi's Stadium
# 0      AT&T Stadium
# dtype: object

# %%
nfl_frame['Stadium'] = stadiums
nfl_frame
# Out:
#    Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0     1           Dallas Cowboys    882  502   374     6  0.573
# 1     2        Green Bay Packers  1,336  737   562    37  0.565
# 2     3            Chicago Bears  1,370  749   579    42  0.562
# 3     4           Miami Dolphins    800  445   351     4  0.559
# 4     5  New England Patriots[b]    884  489   386     9  0.558
#
#    First NFL Season   Division         Stadium
# 0              1960   NFC East    AT&T Stadium
# 1              1921  NFC North             NaN
# 2              1920  NFC North             NaN
# 3              1966   AFC East             NaN
# 4              1960   AFC East  Levi's Stadium

# %%
#Deleting entire column
del nfl_frame['Stadium']
nfl_frame
# Out:
#    Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0     1           Dallas Cowboys    882  502   374     6  0.573
# 1     2        Green Bay Packers  1,336  737   562    37  0.565
# 2     3            Chicago Bears  1,370  749   579    42  0.562
# 3     4           Miami Dolphins    800  445   351     4  0.559
# 4     5  New England Patriots[b]    884  489   386     9  0.558
#
#    First NFL Season   Division
# 0              1960   NFC East
# 1              1921  NFC North
# 2              1920  NFC North
# 3              1966   AFC East
# 4              1960   AFC East

# %%
data = {'City': ['SF', 'LA', 'NYC'], 'Population' : [837000, 3880000, 8400000]}

# %%
#To create a dataframe from a dictionary
city_frame = DataFrame(data)
city_frame
# Out:
#   City  Population
# 0   SF      837000
# 1   LA     3880000
# 2  NYC     8400000
